# %% [markdown]
# # Conhecendo a base de dados

# %% [markdown]
# ## Importando os dados

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
df = pd.read_csv(url, sep=";")
df = df.fillna(0)

# %%
df.head() # df.tail() will show last rows
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         0.0     0.0
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     0.0

# %%
df.describe()
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.296000e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.294598e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.673499e+05
# min        0.000000      0.000000      0.000000      0.000000  0.000000e+00
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#          Condominio          IPTU
# count  3.296000e+04  3.296000e+04
# mean   2.091511e+03  1.630051e+03
# std    3.667970e+04  1.490965e+05
# min    0.000000e+00  0.000000e+00
# 25%    4.500000e+02  0.000000e+00
# 50%    8.500000e+02  1.200000e+02
# 75%    1.630000e+03  4.212500e+02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32960 non-null  float64
#  7   Condominio  32960 non-null  float64
#  8   IPTU        32960 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
np.sort(df["Tipo"].unique())
# Out:
# array(['Apartamento', 'Box/Garagem', 'Casa', 'Casa Comercial',
#        'Casa de Condomínio', 'Casa de Vila', 'Chácara',
#        'Conjunto Comercial/Sala', 'Flat', 'Galpão/Depósito/Armazém',
#        'Hotel', 'Indústria', 'Loft', 'Loja Shopping/ Ct Comercial',
#        'Loja/Salão', 'Loteamento/Condomínio', 'Pousada/Chalé',
#        'Prédio Inteiro', 'Quitinete', 'Studio', 'Sítio', 'Terreno Padrão'],
#       dtype=object)

# %%
type_filtered_df = df[df["Tipo"] == "Apartamento"]

type_filtered_df["Area"].max(), type_filtered_df["Area"].min()
# Out:
# array([  1, 100,   2,   4,   5,   3], dtype=int64)

# %%
df["Quartos"].unique()
# Out:
# array([  1, 100,   2,   4,   5,   3], dtype=int64)

# %%
df[(df["Tipo"] == "Conjunto Comercial/Sala") & (df["Quartos"] != 0)].head()
# Out:
#                          Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 395   Conjunto Comercial/Sala    São Cristóvão        1      1       0    25
# 657   Conjunto Comercial/Sala           Centro      100     39       0  1600
# 1189  Conjunto Comercial/Sala  Barra da Tijuca        1      1       0    36
# 1568  Conjunto Comercial/Sala          Ipanema        2      0       0    45
# 1778  Conjunto Comercial/Sala           Centro        1      0       0   325
#
#          Valor  Condominio     IPTU
# 395      800.0       427.0    471.0
# 657   160000.0         0.0      0.0
# 1189    1300.0       900.0      0.0
# 1568    5000.0      2200.0    245.0
# 1778   10000.0         0.0  10828.0

# %%
df[(df["Area"] >= 150) & (df["Area"] < 250)].head()
# Out:
#                           Tipo    Bairro  Quartos  Vagas  Suites  Area  \
# 4366   Conjunto Comercial/Sala  Flamengo        4      0       0   200
# 7022   Conjunto Comercial/Sala    Centro        4      0       0   200
# 14672  Conjunto Comercial/Sala    Centro        4      0       0   200
#
#          Valor  Condominio   IPTU
# 4366   25000.0      1200.0  300.0
# 7022    5000.0      1779.0  679.0
# 14672   5500.0      1779.0  679.0
